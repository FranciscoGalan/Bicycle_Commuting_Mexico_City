# %%
import requests
import pandas as pd

# %%
# Links to csv files
url_contador = 'https://datos.cdmx.gob.mx/dataset/07d5d501-66dc-4e3e-9d92-bfa163d21434/resource/8548607a-b0c0-4210-962e-1240f715b680/download/ciclista_nuevo.csv'
url_incidentes = ''

# %%
# Get data from the website
get_contador = requests.get(f'{url_contador}')
print(get_contador)
# Out:
# <Response [200]>

# %%
# Read content
content_contador = get_contador.content

# %%
# Create csv files
with open('contador-ciclistas.csv', 'wb') as file:
    file.write(content_contador)

# %%
contador = pd.read_csv('contador-ciclistas.csv')
contador
# Out:
#         21    viernes  28  noviembre  2014    2544     NA   NA.1
# 0       22      lunes  16    febrero  2015  2427.0    NaN    NaN
# 1       23    viernes  17      abril  2015  2726.0    NaN    NaN
# 2       24      lunes  23      marzo  2015    23.0    NaN    NaN
# 3       25  miércoles  24  diciembre  2014   415.0    NaN    NaN
# 4       26    domingo  28  diciembre  2014  1225.0    NaN    NaN
# ...    ...        ...  ..        ...   ...     ...    ...    ...
# 2499  2521  miércoles  24    febrero  2021     NaN  455.0  725.0
# 2500  2522     jueves  25    febrero  2021     NaN  491.0  774.0
# 2501  2523    viernes  26    febrero  2021     NaN  527.0  735.0
# 2502  2524     sabado  27    febrero  2021     NaN  457.0  753.0
# 2503  2525    domingo  28    febrero  2021     NaN  422.0  953.0
#
# [2504 rows x 8 columns]
